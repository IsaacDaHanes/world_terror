# %%
import pandas as pd
import numpy as np

terror_db = pd.read_excel('../databases/globalterrorismdb_0522dist.xlsx')

# %%
terror_db.sample(5)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 26135   198509040007   1985       9     4        NaN         0        NaT
# 19060   198306130015   1983       6    13        NaN         0        NaT
# 8080    197904140004   1979       4    14        NaN         0        NaT
# 157996  201601150040   2016       1    15        NaN         0        NaT
# 119519  201307250012   2013       7    25        NaN         0        NaT
#
#         country    country_txt  region  ... addnotes  \
# 26135       110        Lebanon      10  ...      NaN
# 19060       159           Peru       3  ...      NaN
# 8080         69         France       8  ...      NaN
# 157996      217  United States       1  ...      NaN
# 119519        4    Afghanistan       6  ...      NaN
#
#                                                    scite1  \
# 26135                                                 NaN
# 19060                                                 NaN
# ...

# %%
list(terror_db.columns)
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
# ...

# %%
terror_db.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  2.097060e+05  209706.000000  209706.000000  209706.000000
# mean   2.004867e+11    2004.800993       6.455285      15.527930
# std    1.351933e+09      13.519321       3.387098       8.801104
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.992080e+11    1992.000000       4.000000       8.000000
# 50%    2.012010e+11    2012.000000       6.000000      15.000000
# 75%    2.015123e+11    2015.000000       9.000000      23.000000
# max    2.020123e+11    2020.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  209706.000000  209706.000000  209706.000000  205015.000000
# mean        0.051525     130.291351       7.279854      23.358696
# std         0.221066     111.714562       2.905697      18.137061
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
terror_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209706 entries, 0 to 209705
# Columns: 135 entries, eventid to related
# dtypes: datetime64[ns](1), float64(54), int64(23), object(57)
# memory usage: 216.0+ MB

# %%
rus_ukr_mask = (terror_db['country_txt'] == 'Russia') | (terror_db['country_txt'] == 'Ukraine')

terror_db[rus_ukr_mask].sample(5)
# Out:
#              eventid  iyear  imonth  iday      approxdate  extended  \
# 116123  201304150073   2013       4    15  April 15, 2013         0
# 70775   200007290005   2000       7    29             NaN         0
# 140949  201411250062   2014      11    25             NaN         0
# 71673   200101050005   2001       1     5             NaN         0
# 96767   201006010002   2010       6     1             NaN         0
#
#        resolution  country country_txt  region  ...  \
# 116123        NaT      167      Russia       9  ...
# 70775         NaT      167      Russia       9  ...
# 140949        NaT      214     Ukraine       9  ...
# 71673         NaT      167      Russia       9  ...
# 96767         NaT      167      Russia       9  ...
#
#                                                  addnotes  \
# 116123  Casualty numbers for this attack conflict acro...
# 70775                                                 NaN
# 140949                                                NaN
# ...

# %%
rus_ukr_db = terror_db[rus_ukr_mask]
rus_ukr_db.head()
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 49245  199111270012   1991      11    27        NaN         0        NaT
# 49316  199112010015   1991      12     1        NaN         0        NaT
# 49690  199201060001   1992       1     6        NaN         0        NaT
# 49700  199201060012   1992       1     6        NaN         0        NaT
# 49830  199201170003   1992       1    17        NaN         0        NaT
#
#        country country_txt  region  ... addnotes scite1 scite2  scite3  \
# 49245      214     Ukraine       9  ...      NaN    NaN    NaN     NaN
# 49316      214     Ukraine       9  ...      NaN    NaN    NaN     NaN
# 49690      167      Russia       9  ...      NaN    NaN    NaN     NaN
# 49700      167      Russia       9  ...      NaN    NaN    NaN     NaN
# 49830      167      Russia       9  ...      NaN    NaN    NaN     NaN
#
#        dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...
